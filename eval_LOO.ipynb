# %% [markdown]
# <a href="https://colab.research.google.com/github/ymuto0302/RW2025/blob/main/eval_LOO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.svm import SVC
from sklearn.model_selection import LeaveOneOut, cross_val_score

# Irisデータセットの読み込み
iris = load_iris()
X = iris.data
y = iris.target

# SVCモデルの初期化（線形カーネル）
svc = SVC(kernel='linear')

# LeaveOneOut交差検証器の設定
loo = LeaveOneOut()

# cross_val_score()を使用してLeaveOneOut交差検証を実行
scores = cross_val_score(svc, X, y, cv=loo, scoring='accuracy')

# 結果の表示
print(f"Number of splits: {len(scores)}")
print(f"Mean Accuracy: {np.mean(scores):.4f}")
print(f"Standard Deviation: {np.std(scores):.4f}")
# Out:
# Number of splits: 150
# Mean Accuracy: 0.9800
# Standard Deviation: 0.1400
