# %% [markdown]
# <a href="https://colab.research.google.com/github/ymuto0302/RW2025/blob/main/eval_holdout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# データの読み込み
iris = load_iris()

# データセットのシャッフル & 特徴量とラベルの分離
X, y = shuffle(iris.data, iris.target, random_state=0)

# 学習データとテストデータに分割 (学習:テスト=7:3)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y)

print("shape of X_train:", X_train.shape)
print("shape of y-train:", y_train.shape)

print("shape of X_test", X_test.shape)
print("shape of y_test", y_test.shape)

print("y_test:", y_test)

# これ以降に学習，テストのプロセスを記述する
# Out:
# shape of X_train: (105, 4)
# shape of y-train: (105,)
# shape of X_test (45, 4)
# shape of y_test (45,)
# y_test: [0 1 2 2 1 1 0 1 2 1 2 1 0 2 2 1 0 1 0 2 2 0 0 2 0 1 2 0 1 1 1 2 2 0 0 2 1
#  0 0 2 0 1 2 0 1]
